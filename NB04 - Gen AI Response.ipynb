# %%
# %run NB - Gen AI Config
# Out:
# StatementMeta(, 709c4935-13fa-4f5c-baeb-e1ca8933cc59, 8, Finished, , Finished)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 31.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.3/327.3 kB 62.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 99.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 99.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 24.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# ...

# %%
# from openai import AzureOpenAI
# import json
    
# client = AzureOpenAI(
#     api_key=AZURE_OPENAI_API_KEY,  
#     api_version="2024-02-01",
#     azure_endpoint = AZURE_OPENAI_ENDPOINT
#     )
# MODEL_NAME = 'gpt-4-turbo-2024-04-09'#'gpt-35-turbo'


# MESSAGES = [
#     {"role": "system", "content": "You are a helpful assistant."},
#     {"role": "system", "content": 'vendorID: 1,tripType: 2,PickupDate: 2019-06-21,DropOffDate: 2019-06-21,puYear: 2019,puMonth: 6,passengerCount: 70,tripDistance: 276.0,fareAmount: 597.2,tollsAmount: 24.48,totalAmount: 654.9300000000001'},
#     {"role": "system", "content": 'vendorID: 1,tripType: 1,PickupDate: 2019-06-21,DropOffDate: 2019-06-21,puYear: 2019,puMonth: 6,passengerCount: 3087,tripDistance: 7747.600000000007,fareAmount: 41109.80000000007,tollsAmount: 491.8700000000004,totalAmount: 47980.37000000139'},
#     {"role": "user", "content": "Give me sum of the total amount?"}
#     # {
#     #     "role": "assistant",
#     #     "content": "The Los Angeles Dodgers won the World Series in 2020.",
#     # },
#     # {"role": "user", "content": "Where was it played?"},
# ]

# completion = client.chat.completions.create(
#     model=MODEL_NAME,
#     messages=MESSAGES,
# )

# response = completion.choices[0].message
# print(response.content)
# Out:
# StatementMeta(, 70e807c6-452f-4611-ad27-2eda6377c700, 8, Finished, Available, Finished)
# To find the sum of the total amounts from the two entries:
#
# 1. Total amount from the first entry: 654.93
# 2. Total amount from the second entry: 47980.37
#
# Add these two amounts together:
#
# 654.93 + 47980.37 = 48635.30
#
# The sum of the total amounts is 48635.30.

# %% [markdown]
# #### Sample Response 1

# %%
response = get_response("What is the sum of total amount for vendorID 1 on PickupDate '2019-03-01' by tripType",vendorID=1,PickupDate='2019-03-01')

print(response)
# Out:
# StatementMeta(, e2daa64a-b6be-4ca7-86e8-fcbaae058f33, 12, Finished, Available, Finished)
# To find the sum of the total amount for vendorID 1 on PickupDate '2019-03-01' by tripType, let's categorize and sum the total amounts:
#
# **TripType 1:**
# - TotalAmount: 52283.14000000269
#
# **TripType 2:**
# - TotalAmount: 960.0
#
# These are the total amounts summed by tripType for the given vendorID and PickupDate.

# %% [markdown]
# #### Sample Response 2

# %%
response = get_response("What is the sum of total amount for vendorID 1 on PickupDate '2019-03-01'",vendorID=1,PickupDate='2019-03-01')

print(response)
# Out:
# StatementMeta(, e2daa64a-b6be-4ca7-86e8-fcbaae058f33, 11, Finished, Available, Finished)
# To find the sum of the total amount for vendorID 1 on PickupDate '2019-03-01', we need to add up the total amounts for all trips that match these criteria.
#
# Here are the entries for PickupDate '2019-03-01' with vendorID 1:
#
# 1. totalAmount: 52283.14000000269
# 2. totalAmount: 960.0
#
# Adding them up:
# \( 52283.14 + 960.0 = 53243.14 \)
#
# Therefore, the sum of the total amount for vendorID 1 on PickupDate '2019-03-01' is **$53,243.14**.

# %% [markdown]
# #### Sample Response 3

# %%
response = get_response("What is the sum of total amount for vendorID 1 on the month February 2019",vendorID=1,puMonth=2,puYear=2019)

print(response)
# Out:
# StatementMeta(, 709c4935-13fa-4f5c-baeb-e1ca8933cc59, 9, Finished, Available, Finished)
# To get the sum of the total amount for vendorID 1 in February 2019, we will add up all the totalAmount figures provided for that vendor and month:
#
# \[
# ...

# %% [markdown]
# #### Sample Response 4

# %%
response = get_response("Give me the top 10 total amount for vendorID 1 on the month March 2019",vendorID=1,puMonth=3,puYear=2019)

print(response)
# Out:
# StatementMeta(, e2daa64a-b6be-4ca7-86e8-fcbaae058f33, 9, Finished, Available, Finished)
# Here are the top 10 total amounts for vendorID 1 in March 2019:
#
# 1. **Total Amount: $52,283.14**
#    - Pickup Date: 2019-03-01
#    - DropOff Date: 2019-03-01
#    - Trip Distance: 9926.3 miles
#    - Fare Amount: $44,020.95
#    - Tolls Amount: $636.34
#
# 2. **Total Amount: $51,856.20**
#    - Pickup Date: 2019-03-14
#    - DropOff Date: 2019-03-14
#    - Trip Distance: 9907.4 miles
#    - Fare Amount: $43,439.70
#    - Tolls Amount: $584.10
#
# 3. **Total Amount: $51,115.00**
#    - Pickup Date: 2019-03-08
#    - DropOff Date: 2019-03-08
#    - Trip Distance: 8703.4 miles
#    - Fare Amount: $42,934.80
#    - Tolls Amount: $473.58
#
# 4. **Total Amount: $50,410.68**
#    - Pickup Date: 2019-03-15
#    - DropOff Date: 2019-03-15
#    - Trip Distance: 9445.1 miles
#    - Fare Amount: $42,014.91
#    - Tolls Amount: $599.50
#
# 5. **Total Amount: $49,478.96**
#    - Pickup Date: 2019-03-22
# ...

# %% [markdown]
# #### Sample Response 5

# %%
response = get_response("Give me the top 10 total amount for vendorID 1 in the month of April 2019",vendorID=1,puMonth=3,puYear=2019)

print(response)
# Out:
# StatementMeta(, 709c4935-13fa-4f5c-baeb-e1ca8933cc59, 10, Finished, Available, Finished)
# The information provided includes only the month of March 2019 and does not contain data for April 2019. Please provide the relevant data for April 2019 so I can assist you with that request.
